# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
sns.set_style("darkgrid")
sns.set_context("talk")

# %%
sns.set_style("darkgrid") # darkgrid style
sns.set_context("talk")  # font size
sns.set_style('darkgrid',{'xtick.bottom': True, 'ytick.left': True}) # customize like a pro
sns.axes_style()

SMALL_SIZE = 20
MEDIUM_SIZE = 22
BIGGER_SIZE = 24
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
df_hist = pd.read_csv('model_history_color_hist_50drop.csv', index_col=False)
df_hist
# Out:
#     Unnamed: 0      loss  accuracy  val_loss  val_accuracy
# 0            0  1.932164  0.295063  5.918438      0.519481
# 1            1  1.690628  0.365098  2.721019      0.519481
# 2            2  1.239642  0.541906  1.683825      0.084416
# 3            3  0.800633  0.711825  1.091360      0.584416
# 4            4  0.601236  0.778416  0.904253      0.662338
# 5            5  0.457426  0.830080  0.883636      0.662338
# 6            6  0.318423  0.873708  0.783649      0.733766
# 7            7  0.221482  0.924225  0.583705      0.811688
# 8            8  0.909088  0.693456  0.959250      0.616883
# 9            9  0.501820  0.809414  0.699019      0.772727
# 10          10  0.320166  0.892078  0.618788      0.811688
# 11          11  0.172665  0.932262  0.472831      0.811688
# 12          12  0.171905  0.941447  0.505068      0.818182
# 13          13  0.099258  0.963261  0.638718      0.824675
# 14          14  0.061970  0.979334  0.602852      0.837662
# 15          15  0.046229  0.980482  0.596229      0.805195
# 16          16  0.055349  0.980482  0.739689      0.857143
# 17          17  0.045794  0.987371  1.097240      0.824675

# %%
fig, axe = plt.subplots(figsize=(6, 6))
plt.plot(np.arange(1, 19),df_hist['accuracy'], label='Training')
plt.plot(np.arange(1, 19),df_hist['val_accuracy'], label='Validation')
plt.xlim(1, 18)
tik = np.arange(2, 19, 2)
tik = np.insert(tik, 0, 1)
plt.xticks(tik)
plt.xlabel('Epochs', labelpad=10)
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.savefig('accuracy.png')



fig, axe = plt.subplots(figsize=(6, 6))
plt.plot(np.arange(1, 19),df_hist['loss'], label='Training')
plt.plot(np.arange(1, 19),df_hist['val_loss'], label='Validation')
plt.xlim(1, 18)
tik = np.arange(2, 19, 2)
tik = np.insert(tik, 0, 1)
plt.xticks(tik)
plt.xlabel('Epochs', labelpad=10)
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('Loss.png')

# %%
fig, axe = plt.subplots(figsize=(6, 6))
df_y = pd.read_csv('TrainAnnotations.csv', index_col=False)
bin_val = np.arange(0, 6, 1) - 0.5
sns.distplot(df_y['annotation'], kde=False, bins=bin_val)
# plt.xlim(-0.1,4.1)
plt.xticks(np.arange(0,5, 1))
plt.ylabel("Training Set: Bin Count", labelpad=10)
plt.xlabel('Classification')
plt.tight_layout()
plt.savefig('training_set_histogram.png')

# %%
fig, axe = plt.subplots(figsize=(6, 6))
df_pred = pd.read_csv('ModelPredictioncolor_hist_50drop.csv', index_col=False)
bin_val = np.arange(0, 6, 1) - 0.5
sns.distplot(df_pred['0'], kde=False, bins=bin_val)
# plt.xlim(-0.1,4.1)
plt.xticks(np.arange(0,5, 1))
plt.ylabel("Test Set: Bin Count", labelpad=10)
plt.xlabel('Classification')
plt.tight_layout()
plt.savefig('test_set_histogram.png')
